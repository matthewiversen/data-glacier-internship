# %% [markdown]
# ## Imports

# %%
import pandas as pd

# working with excel files
# %pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\matthew iversen\appdata\local\programs\python\python310\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\matthew iversen\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Util File

# %%
# %%writefile testutility.py
import logging
import os
import subprocess
import yaml
import pandas as pd
import datetime 
import gc
import re
import difflib


# summary of a data file
def summary(df: pd.DataFrame, file_path: str) -> None:
    # filesize in mb
    file_size_bytes = os.path.getsize(file_path)
    file_size_mb = file_size_bytes / (1024 * 1024)

    # get dimensions
    total_rows = len(df)
    total_columns = len(df.columns)

    print(f"Total number of rows: {total_rows}")
    print(f"Total number of columns: {total_columns}")
    print(f"File size: {file_size_mb:.2f} MB")


# prints the number of nans in each column
def show_nan_all_columns(df: pd.DataFrame) -> None:
    nan_counts = df.isnull().sum().sort_values(ascending=False)
    print(f"NaN Counts:\n{nan_counts}")
    

# prints the number of nans in columns with nans
def show_nan_columns(df: pd.DataFrame) -> None:
    nan_counts = df.isnull().sum().sort_values(ascending=False)
    nan_counts = nan_counts[nan_counts > 0]
    print(f"NaN Counts:\n{nan_counts}")
    

# returns what features have nans
def find_nan_columns(df: pd.DataFrame) -> pd.Index:
    nan_features = df.isnull().sum()
    non_zero_nans = nan_features[nan_features > 0]
    return non_zero_nans.index


# changes the number of columns seen on output
def set_pd_max_columns(max_columns: int | None) -> None:
    pd.set_option("display.max_columns", max_columns)


# changes the number of rows seen on output
def set_pd_max_rows(max_rows: int | None) -> None:
    pd.set_option("display.max_rows", max_rows)


def detect_outliers_iqr(data: pd.DataFrame) -> pd.DataFrame:
    """
    Detects and returns any outliers for a given dataframe.
    """
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # filter for outliers
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    return outliers


def show_spelling_errors(
    df: pd.DataFrame, similarity_threshold: float, exclude_columns: list[str]
) -> None:
    """This prints all of the observations in a column that are similar above a threshold

    Args:
        df (pd.DataFrame): Pandas DataFrame
        similarity_threshold (float): Decimal of how similar of results we want to see (0.0-1.0)
        exclude_columns (list[str]): List of columns you want to exclude from spelling check
    """

    spelling_errors = {}

    if exclude_columns is None:
        exclude_columns = []

    # find potential spelling errors for object columns
    for column in df.select_dtypes(include="object"):
        if column not in exclude_columns:
            unique_values = df[column].dropna().unique()
            potential_errors = []

            for i, value1 in enumerate(unique_values):
                for value2 in unique_values[i + 1 :]:
                    similarity = difflib.SequenceMatcher(None, value1, value2).ratio()
                    if similarity > similarity_threshold:
                        potential_errors.append((value1, value2))

            if potential_errors:
                spelling_errors[column] = potential_errors

    # print the errors
    for column, errors in spelling_errors.items():
        print(f"Potential spelling errors in column '{column}':")
        for error in errors:
            print(f"- '{error[0]}' might be similar to '{error[1]}'")
# Out:
# Overwriting testutility.py

# %%
# import util file for use
import testutility as util

# %% [markdown]
# ## Read Data

# %%
file_path = "../week-7/Healthcare_dataset.xlsx"
df = pd.read_excel(file_path, sheet_name=1)  # data is on the second sheet of the file

util.set_pd_max_columns(None)
util.set_pd_max_rows(None)
df.head()
# Out:
#   Ptid Persistency_Flag  Gender           Race     Ethnicity   Region  \
# 0   P1       Persistent    Male      Caucasian  Not Hispanic     West
# 1   P2   Non-Persistent    Male          Asian  Not Hispanic     West
# 2   P3   Non-Persistent  Female  Other/Unknown      Hispanic  Midwest
# 3   P4   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
# 4   P5   Non-Persistent  Female      Caucasian  Not Hispanic  Midwest
#
#   Age_Bucket        Ntm_Speciality Ntm_Specialist_Flag  \
# 0        >75  GENERAL PRACTITIONER              Others
# 1      55-65  GENERAL PRACTITIONER              Others
# 2      65-75  GENERAL PRACTITIONER              Others
# 3        >75  GENERAL PRACTITIONER              Others
# 4        >75  GENERAL PRACTITIONER              Others
#
#        Ntm_Speciality_Bucket Gluco_Record_Prior_Ntm Gluco_Record_During_Rx  \
# 0  OB/GYN/Others/PCP/Unknown                      N                      N
# 1  OB/GYN/Others/PCP/Unknown                      N                      N
# 2  OB/GYN/Others/PCP/Unknown                      N                      N
# 3  OB/GYN/Others/PCP/Unknown                      N                      Y
# 4  OB/GYN/Others/PCP/Unknown                      Y                      Y
#
#    Dexa_Freq_During_Rx Dexa_During_Rx Frag_Frac_Prior_Ntm Frag_Frac_During_Rx  \
# 0                    0              N                   N                   N
# 1                    0              N                   N                   N
# 2                    0              N                   N                   N
# 3                    0              N                   N                   N
# 4                    0              N                   N                   N
#
#   Risk_Segment_Prior_Ntm Tscore_Bucket_Prior_Ntm Risk_Segment_During_Rx  \
# 0                 VLR_LR                   >-2.5                 VLR_LR
# 1                 VLR_LR                   >-2.5                Unknown
# 2                 HR_VHR                  <=-2.5                 HR_VHR
# 3                 HR_VHR                   >-2.5                 HR_VHR
# 4                 HR_VHR                  <=-2.5                Unknown
#
#   Tscore_Bucket_During_Rx Change_T_Score Change_Risk_Segment Adherent_Flag  \
# 0                  <=-2.5      No change             Unknown      Adherent
# 1                 Unknown        Unknown             Unknown      Adherent
# 2                  <=-2.5      No change           No change      Adherent
# 3                  <=-2.5      No change           No change      Adherent
# 4                 Unknown        Unknown             Unknown      Adherent
#
#   Idn_Indicator Injectable_Experience_During_Rx  \
# 0             N                               Y
# 1             N                               Y
# 2             N                               Y
# 3             N                               Y
# 4             N                               Y
#
#   Comorb_Encounter_For_Screening_For_Malignant_Neoplasms  \
# 0                                                  N
# 1                                                  N
# 2                                                  Y
# 3                                                  N
# 4                                                  Y
#
#   Comorb_Encounter_For_Immunization  \
# 0                                 Y
# 1                                 N
# 2                                 N
# 3                                 Y
# 4                                 Y
#
#   Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx  \
# 0                                                  Y
# 1                                                  Y
# 2                                                  Y
# 3                                                  Y
# 4                                                  Y
#
#   Comorb_Vitamin_D_Deficiency  \
# 0                           N
# 1                           N
# 2                           N
# 3                           N
# 4                           N
#
#   Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  Y
# 4                                                  N
#
#   Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx  \
# 0                                                  Y
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Comorb_Long_Term_Current_Drug_Therapy Comorb_Dorsalgia  \
# 0                                     N                Y
# 1                                     N                N
# 2                                     N                N
# 3                                     N                Y
# 4                                     N                Y
#
#   Comorb_Personal_History_Of_Other_Diseases_And_Conditions  \
# 0                                                  Y
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  Y
#
#   Comorb_Other_Disorders_Of_Bone_Density_And_Structure  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  Y
# 4                                                  N
#
#   Comorb_Osteoporosis_without_current_pathological_fracture  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Comorb_Personal_history_of_malignant_neoplasm  \
# 0                                             N
# 1                                             N
# 2                                             N
# 3                                             N
# 4                                             N
#
#   Comorb_Gastro_esophageal_reflux_disease  \
# 0                                       N
# 1                                       N
# 2                                       N
# 3                                       Y
# 4                                       N
#
#   Concom_Cholesterol_And_Triglyceride_Regulating_Preparations  \
# 0                                                  N
# 1                                                  N
# 2                                                  Y
# 3                                                  N
# 4                                                  N
#
#   Concom_Narcotics Concom_Systemic_Corticosteroids_Plain  \
# 0                N                                     N
# 1                N                                     N
# 2                N                                     N
# 3                Y                                     Y
# 4                Y                                     Y
#
#   Concom_Anti_Depressants_And_Mood_Stabilisers Concom_Fluoroquinolones  \
# 0                                            N                       N
# 1                                            N                       N
# 2                                            N                       N
# 3                                            N                       N
# 4                                            Y                       N
#
#   Concom_Cephalosporins Concom_Macrolides_And_Similar_Types  \
# 0                     N                                   N
# 1                     N                                   N
# 2                     N                                   N
# 3                     N                                   N
# 4                     N                                   N
#
#   Concom_Broad_Spectrum_Penicillins Concom_Anaesthetics_General  \
# 0                                 N                           N
# 1                                 N                           N
# 2                                 N                           N
# 3                                 N                           N
# 4                                 N                           N
#
#   Concom_Viral_Vaccines Risk_Type_1_Insulin_Dependent_Diabetes  \
# 0                     N                                      N
# 1                     N                                      N
# 2                     N                                      N
# 3                     Y                                      N
# 4                     N                                      N
#
#   Risk_Osteogenesis_Imperfecta Risk_Rheumatoid_Arthritis  \
# 0                            N                         N
# 1                            N                         N
# 2                            N                         N
# 3                            N                         N
# 4                            N                         N
#
#   Risk_Untreated_Chronic_Hyperthyroidism Risk_Untreated_Chronic_Hypogonadism  \
# 0                                      N                                   N
# 1                                      N                                   N
# 2                                      N                                   N
# 3                                      N                                   N
# 4                                      N                                   N
#
#   Risk_Untreated_Early_Menopause Risk_Patient_Parent_Fractured_Their_Hip  \
# 0                              N                                       N
# 1                              N                                       N
# 2                              N                                       Y
# 3                              N                                       N
# 4                              N                                       N
#
#   Risk_Smoking_Tobacco Risk_Chronic_Malnutrition_Or_Malabsorption  \
# 0                    N                                          N
# 1                    N                                          N
# 2                    N                                          N
# 3                    Y                                          N
# 4                    Y                                          N
#
#   Risk_Chronic_Liver_Disease Risk_Family_History_Of_Osteoporosis  \
# 0                          N                                   N
# 1                          N                                   N
# 2                          N                                   N
# 3                          N                                   N
# 4                          N                                   N
#
#   Risk_Low_Calcium_Intake Risk_Vitamin_D_Insufficiency  \
# 0                       N                            N
# 1                       N                            N
# 2                       Y                            N
# 3                       N                            N
# 4                       N                            N
#
#   Risk_Poor_Health_Frailty Risk_Excessive_Thinness  \
# 0                        N                       N
# 1                        N                       N
# 2                        N                       N
# 3                        N                       N
# 4                        N                       N
#
#   Risk_Hysterectomy_Oophorectomy Risk_Estrogen_Deficiency Risk_Immobilization  \
# 0                              N                        N                   N
# 1                              N                        N                   N
# 2                              N                        N                   N
# 3                              N                        N                   N
# 4                              N                        N                   N
#
#   Risk_Recurring_Falls  Count_Of_Risks
# 0                    N               0
# 1                    N               0
# 2                    N               2
# 3                    N               1
# 4                    N               1

# %% [markdown]
# ## Summarize Data

# %%
# use util summary
util.summary(df, file_path)
# Out:
# Total number of rows: 3424
# Total number of columns: 69
# File size: 0.88 MB

# %% [markdown]
# ## Look at Feature Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3424 entries, 0 to 3423
# Data columns (total 69 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Ptid                                                                3424 non-null   object
#  1   Persistency_Flag                                                    3424 non-null   object
#  2   Gender                                                              3424 non-null   object
#  3   Race                                                                3424 non-null   object
#  4   Ethnicity                                                           3424 non-null   object
#  5   Region                                                              3424 non-null   object
#  6   Age_Bucket                                                          3424 non-null   object
#  7   Ntm_Speciality                                                      3424 non-null   object
#  8   Ntm_Specialist_Flag                                                 3424 non-null   object
#  9   Ntm_Speciality_Bucket                                               3424 non-null   object
#  10  Gluco_Record_Prior_Ntm                                              3424 non-null   object
#  11  Gluco_Record_During_Rx                                              3424 non-null   object
#  12  Dexa_Freq_During_Rx                                                 3424 non-null   int64
#  13  Dexa_During_Rx                                                      3424 non-null   object
#  14  Frag_Frac_Prior_Ntm                                                 3424 non-null   object
#  15  Frag_Frac_During_Rx                                                 3424 non-null   object
#  16  Risk_Segment_Prior_Ntm                                              3424 non-null   object
#  17  Tscore_Bucket_Prior_Ntm                                             3424 non-null   object
#  18  Risk_Segment_During_Rx                                              3424 non-null   object
#  19  Tscore_Bucket_During_Rx                                             3424 non-null   object
#  20  Change_T_Score                                                      3424 non-null   object
#  21  Change_Risk_Segment                                                 3424 non-null   object
#  22  Adherent_Flag                                                       3424 non-null   object
#  23  Idn_Indicator                                                       3424 non-null   object
#  24  Injectable_Experience_During_Rx                                     3424 non-null   object
#  25  Comorb_Encounter_For_Screening_For_Malignant_Neoplasms              3424 non-null   object
#  26  Comorb_Encounter_For_Immunization                                   3424 non-null   object
#  27  Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx     3424 non-null   object
#  28  Comorb_Vitamin_D_Deficiency                                         3424 non-null   object
#  29  Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified                3424 non-null   object
#  30  Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx  3424 non-null   object
#  31  Comorb_Long_Term_Current_Drug_Therapy                               3424 non-null   object
#  32  Comorb_Dorsalgia                                                    3424 non-null   object
#  33  Comorb_Personal_History_Of_Other_Diseases_And_Conditions            3424 non-null   object
#  34  Comorb_Other_Disorders_Of_Bone_Density_And_Structure                3424 non-null   object
#  35  Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias     3424 non-null   object
#  36  Comorb_Osteoporosis_without_current_pathological_fracture           3424 non-null   object
#  37  Comorb_Personal_history_of_malignant_neoplasm                       3424 non-null   object
#  38  Comorb_Gastro_esophageal_reflux_disease                             3424 non-null   object
#  39  Concom_Cholesterol_And_Triglyceride_Regulating_Preparations         3424 non-null   object
#  40  Concom_Narcotics                                                    3424 non-null   object
#  41  Concom_Systemic_Corticosteroids_Plain                               3424 non-null   object
#  42  Concom_Anti_Depressants_And_Mood_Stabilisers                        3424 non-null   object
#  43  Concom_Fluoroquinolones                                             3424 non-null   object
#  44  Concom_Cephalosporins                                               3424 non-null   object
#  45  Concom_Macrolides_And_Similar_Types                                 3424 non-null   object
#  46  Concom_Broad_Spectrum_Penicillins                                   3424 non-null   object
#  47  Concom_Anaesthetics_General                                         3424 non-null   object
#  48  Concom_Viral_Vaccines                                               3424 non-null   object
#  49  Risk_Type_1_Insulin_Dependent_Diabetes                              3424 non-null   object
#  50  Risk_Osteogenesis_Imperfecta                                        3424 non-null   object
#  51  Risk_Rheumatoid_Arthritis                                           3424 non-null   object
#  52  Risk_Untreated_Chronic_Hyperthyroidism                              3424 non-null   object
#  53  Risk_Untreated_Chronic_Hypogonadism                                 3424 non-null   object
#  54  Risk_Untreated_Early_Menopause                                      3424 non-null   object
#  55  Risk_Patient_Parent_Fractured_Their_Hip                             3424 non-null   object
#  56  Risk_Smoking_Tobacco                                                3424 non-null   object
#  57  Risk_Chronic_Malnutrition_Or_Malabsorption                          3424 non-null   object
#  58  Risk_Chronic_Liver_Disease                                          3424 non-null   object
#  59  Risk_Family_History_Of_Osteoporosis                                 3424 non-null   object
#  60  Risk_Low_Calcium_Intake                                             3424 non-null   object
#  61  Risk_Vitamin_D_Insufficiency                                        3424 non-null   object
#  62  Risk_Poor_Health_Frailty                                            3424 non-null   object
#  63  Risk_Excessive_Thinness                                             3424 non-null   object
#  64  Risk_Hysterectomy_Oophorectomy                                      3424 non-null   object
#  65  Risk_Estrogen_Deficiency                                            3424 non-null   object
#  66  Risk_Immobilization                                                 3424 non-null   object
#  67  Risk_Recurring_Falls                                                3424 non-null   object
#  68  Count_Of_Risks                                                      3424 non-null   int64
# dtypes: int64(2), object(67)
# memory usage: 1.8+ MB

# %% [markdown]
# The only two columns that are int64 are the correct type, while the rest are objects as expected.

# %% [markdown]
# ## Checking for Outliers

# %%
df.Dexa_Freq_During_Rx.unique(), df.Count_Of_Risks.unique()
# Out:
# (array([  0,   2,   7,   3,   5,  20,  13,   1,   6,  12,   4,  10,  25,
#          11,  18,  21,  15,  28,  22,  37,  14,   8,   9,  17,  81,  42,
#          16,  30,  19,  45,  27,  24,  58,  26,  23,  33, 110,  36,  34,
#          88,  66,  32, 118,  48,  69,  38,  40,  68,  52,  50, 146,  44,
#          35,  39, 108,  54,  72,  29], dtype=int64),
#  array([0, 2, 1, 3, 4, 5, 6, 7], dtype=int64))

# %% [markdown]
# In the context of these features, neither appear to have outliers. The remainder of the features are categorical.

# %% [markdown]
# ## Check Spelling

# %%
util.show_spelling_errors(df, 0.85)
# Out:
# Potential spelling errors in column 'Ptid':
# - 'P10' might be similar to 'P100'
# - 'P10' might be similar to 'P101'
# - 'P10' might be similar to 'P102'
# - 'P10' might be similar to 'P103'
# - 'P10' might be similar to 'P104'
# - 'P10' might be similar to 'P105'
# - 'P10' might be similar to 'P106'
# - 'P10' might be similar to 'P107'
# - 'P10' might be similar to 'P108'
# - 'P10' might be similar to 'P109'
# - 'P10' might be similar to 'P110'
# - 'P10' might be similar to 'P120'
# - 'P10' might be similar to 'P130'
# - 'P10' might be similar to 'P140'
# - 'P10' might be similar to 'P150'
# - 'P10' might be similar to 'P160'
# - 'P10' might be similar to 'P170'
# - 'P10' might be similar to 'P180'
# - 'P10' might be similar to 'P190'
# - 'P10' might be similar to 'P210'
# - 'P10' might be similar to 'P310'
# - 'P10' might be similar to 'P410'
# - 'P10' might be similar to 'P510'
# - 'P10' might be similar to 'P610'
# - 'P10' might be similar to 'P710'
# - 'P10' might be similar to 'P810'
# - 'P10' might be similar to 'P910'
# - 'P11' might be similar to 'P101'
# - 'P11' might be similar to 'P110'
# - 'P11' might be similar to 'P111'
# - 'P11' might be similar to 'P112'
# - 'P11' might be similar to 'P113'
# - 'P11' might be similar to 'P114'
# - 'P11' might be similar to 'P115'
# - 'P11' might be similar to 'P116'
# - 'P11' might be similar to 'P117'
# - 'P11' might be similar to 'P118'
# - 'P11' might be similar to 'P119'
# - 'P11' might be similar to 'P121'
# - 'P11' might be similar to 'P131'
# - 'P11' might be similar to 'P141'
# - 'P11' might be similar to 'P151'
# - 'P11' might be similar to 'P161'
# - 'P11' might be similar to 'P171'
# - 'P11' might be similar to 'P181'
# - 'P11' might be similar to 'P191'
# - 'P11' might be similar to 'P211'
# - 'P11' might be similar to 'P311'
# - 'P11' might be similar to 'P411'
# - 'P11' might be similar to 'P511'
# - 'P11' might be similar to 'P611'
# - 'P11' might be similar to 'P711'
# - 'P11' might be similar to 'P811'
# - 'P11' might be similar to 'P911'
# - 'P12' might be similar to 'P102'
# - 'P12' might be similar to 'P112'
# - 'P12' might be similar to 'P120'
# - 'P12' might be similar to 'P121'
# - 'P12' might be similar to 'P122'
# - 'P12' might be similar to 'P123'
# - 'P12' might be similar to 'P124'
# - 'P12' might be similar to 'P125'
# - 'P12' might be similar to 'P126'
# - 'P12' might be similar to 'P127'
# - 'P12' might be similar to 'P128'
# - 'P12' might be similar to 'P129'
# - 'P12' might be similar to 'P132'
# - 'P12' might be similar to 'P142'
# - 'P12' might be similar to 'P152'
# - 'P12' might be similar to 'P162'
# - 'P12' might be similar to 'P172'
# - 'P12' might be similar to 'P182'
# - 'P12' might be similar to 'P192'
# - 'P12' might be similar to 'P212'
# - 'P12' might be similar to 'P312'
# - 'P12' might be similar to 'P412'
# - 'P12' might be similar to 'P512'
# - 'P12' might be similar to 'P612'
# - 'P12' might be similar to 'P712'
# - 'P12' might be similar to 'P812'
# - 'P12' might be similar to 'P912'
# - 'P13' might be similar to 'P103'
# - 'P13' might be similar to 'P113'
# - 'P13' might be similar to 'P123'
# - 'P13' might be similar to 'P130'
# - 'P13' might be similar to 'P131'
# - 'P13' might be similar to 'P132'
# - 'P13' might be similar to 'P133'
# - 'P13' might be similar to 'P134'
# - 'P13' might be similar to 'P135'
# - 'P13' might be similar to 'P136'
# - 'P13' might be similar to 'P137'
# - 'P13' might be similar to 'P138'
# - 'P13' might be similar to 'P139'
# - 'P13' might be similar to 'P143'
# - 'P13' might be similar to 'P153'
# - 'P13' might be similar to 'P163'
# - 'P13' might be similar to 'P173'
# - 'P13' might be similar to 'P183'
# - 'P13' might be similar to 'P193'
# - 'P13' might be similar to 'P213'
# - 'P13' might be similar to 'P313'
# - 'P13' might be similar to 'P413'
# - 'P13' might be similar to 'P513'
# - 'P13' might be similar to 'P613'
# - 'P13' might be similar to 'P713'
# - 'P13' might be similar to 'P813'
# - 'P13' might be similar to 'P913'
# - 'P14' might be similar to 'P104'
# - 'P14' might be similar to 'P114'
# - 'P14' might be similar to 'P124'
# - 'P14' might be similar to 'P134'
# - 'P14' might be similar to 'P140'
# - 'P14' might be similar to 'P141'
# - 'P14' might be similar to 'P142'
# - 'P14' might be similar to 'P143'
# - 'P14' might be similar to 'P144'
# - 'P14' might be similar to 'P145'
# - 'P14' might be similar to 'P146'
# - 'P14' might be similar to 'P147'
# - 'P14' might be similar to 'P148'
# - 'P14' might be similar to 'P149'
# - 'P14' might be similar to 'P154'
# - 'P14' might be similar to 'P164'
# - 'P14' might be similar to 'P174'
# - 'P14' might be similar to 'P184'
# - 'P14' might be similar to 'P194'
# - 'P14' might be similar to 'P214'
# - 'P14' might be similar to 'P314'
# - 'P14' might be similar to 'P414'
# - 'P14' might be similar to 'P514'
# - 'P14' might be similar to 'P614'
# - 'P14' might be similar to 'P714'
# - 'P14' might be similar to 'P814'
# - 'P14' might be similar to 'P914'
# - 'P15' might be similar to 'P105'
# - 'P15' might be similar to 'P115'
# - 'P15' might be similar to 'P125'
# - 'P15' might be similar to 'P135'
# - 'P15' might be similar to 'P145'
# - 'P15' might be similar to 'P150'
# - 'P15' might be similar to 'P151'
# - 'P15' might be similar to 'P152'
# - 'P15' might be similar to 'P153'
# - 'P15' might be similar to 'P154'
# - 'P15' might be similar to 'P155'
# - 'P15' might be similar to 'P156'
# - 'P15' might be similar to 'P157'
# - 'P15' might be similar to 'P158'
# - 'P15' might be similar to 'P159'
# - 'P15' might be similar to 'P165'
# - 'P15' might be similar to 'P175'
# - 'P15' might be similar to 'P185'
# - 'P15' might be similar to 'P195'
# - 'P15' might be similar to 'P215'
# - 'P15' might be similar to 'P315'
# - 'P15' might be similar to 'P415'
# - 'P15' might be similar to 'P515'
# - 'P15' might be similar to 'P615'
# - 'P15' might be similar to 'P715'
# - 'P15' might be similar to 'P815'
# - 'P15' might be similar to 'P915'
# - 'P16' might be similar to 'P106'
# - 'P16' might be similar to 'P116'
# - 'P16' might be similar to 'P126'
# - 'P16' might be similar to 'P136'
# - 'P16' might be similar to 'P146'
# - 'P16' might be similar to 'P156'
# - 'P16' might be similar to 'P160'
# - 'P16' might be similar to 'P161'
# - 'P16' might be similar to 'P162'
# - 'P16' might be similar to 'P163'
# - 'P16' might be similar to 'P164'
# - 'P16' might be similar to 'P165'
# - 'P16' might be similar to 'P166'
# - 'P16' might be similar to 'P167'
# - 'P16' might be similar to 'P168'
# - 'P16' might be similar to 'P169'
# - 'P16' might be similar to 'P176'
# - 'P16' might be similar to 'P186'
# - 'P16' might be similar to 'P196'
# - 'P16' might be similar to 'P216'
# - 'P16' might be similar to 'P316'
# - 'P16' might be similar to 'P416'
# - 'P16' might be similar to 'P516'
# - 'P16' might be similar to 'P616'
# - 'P16' might be similar to 'P716'
# - 'P16' might be similar to 'P816'
# - 'P16' might be similar to 'P916'
# - 'P17' might be similar to 'P107'
# - 'P17' might be similar to 'P117'
# - 'P17' might be similar to 'P127'
# - 'P17' might be similar to 'P137'
# - 'P17' might be similar to 'P147'
# - 'P17' might be similar to 'P157'
# - 'P17' might be similar to 'P167'
# - 'P17' might be similar to 'P170'
# - 'P17' might be similar to 'P171'
# - 'P17' might be similar to 'P172'
# - 'P17' might be similar to 'P173'
# - 'P17' might be similar to 'P174'
# - 'P17' might be similar to 'P175'
# - 'P17' might be similar to 'P176'
# - 'P17' might be similar to 'P177'
# - 'P17' might be similar to 'P178'
# - 'P17' might be similar to 'P179'
# - 'P17' might be similar to 'P187'
# - 'P17' might be similar to 'P197'
# - 'P17' might be similar to 'P217'
# - 'P17' might be similar to 'P317'
# - 'P17' might be similar to 'P417'
# - 'P17' might be similar to 'P517'
# - 'P17' might be similar to 'P617'
# - 'P17' might be similar to 'P717'
# - 'P17' might be similar to 'P817'
# - 'P17' might be similar to 'P917'
# - 'P18' might be similar to 'P108'
# - 'P18' might be similar to 'P118'
# - 'P18' might be similar to 'P128'
# - 'P18' might be similar to 'P138'
# - 'P18' might be similar to 'P148'
# - 'P18' might be similar to 'P158'
# - 'P18' might be similar to 'P168'
# - 'P18' might be similar to 'P178'
# - 'P18' might be similar to 'P180'
# - 'P18' might be similar to 'P181'
# - 'P18' might be similar to 'P182'
# - 'P18' might be similar to 'P183'
# - 'P18' might be similar to 'P184'
# - 'P18' might be similar to 'P185'
# - 'P18' might be similar to 'P186'
# - 'P18' might be similar to 'P187'
# - 'P18' might be similar to 'P188'
# - 'P18' might be similar to 'P189'
# - 'P18' might be similar to 'P198'
# - 'P18' might be similar to 'P218'
# - 'P18' might be similar to 'P318'
# - 'P18' might be similar to 'P418'
# - 'P18' might be similar to 'P518'
# - 'P18' might be similar to 'P618'
# - 'P18' might be similar to 'P718'
# - 'P18' might be similar to 'P818'
# - 'P18' might be similar to 'P918'
# - 'P19' might be similar to 'P109'
# - 'P19' might be similar to 'P119'
# - 'P19' might be similar to 'P129'
# - 'P19' might be similar to 'P139'
# - 'P19' might be similar to 'P149'
# - 'P19' might be similar to 'P159'
# - 'P19' might be similar to 'P169'
# - 'P19' might be similar to 'P179'
# - 'P19' might be similar to 'P189'
# - 'P19' might be similar to 'P190'
# - 'P19' might be similar to 'P191'
# - 'P19' might be similar to 'P192'
# - 'P19' might be similar to 'P193'
# - 'P19' might be similar to 'P194'
# - 'P19' might be similar to 'P195'
# - 'P19' might be similar to 'P196'
# - 'P19' might be similar to 'P197'
# - 'P19' might be similar to 'P198'
# - 'P19' might be similar to 'P199'
# - 'P19' might be similar to 'P219'
# - 'P19' might be similar to 'P319'
# - 'P19' might be similar to 'P419'
# - 'P19' might be similar to 'P519'
# - 'P19' might be similar to 'P619'
# - 'P19' might be similar to 'P719'
# - 'P19' might be similar to 'P819'
# - 'P19' might be similar to 'P919'
# - 'P20' might be similar to 'P120'
# - 'P20' might be similar to 'P200'
# - 'P20' might be similar to 'P201'
# - 'P20' might be similar to 'P202'
# - 'P20' might be similar to 'P203'
# - 'P20' might be similar to 'P204'
# - 'P20' might be similar to 'P205'
# - 'P20' might be similar to 'P206'
# - 'P20' might be similar to 'P207'
# - 'P20' might be similar to 'P208'
# - 'P20' might be similar to 'P209'
# - 'P20' might be similar to 'P210'
# - 'P20' might be similar to 'P220'
# - 'P20' might be similar to 'P230'
# - 'P20' might be similar to 'P240'
# - 'P20' might be similar to 'P250'
# - 'P20' might be similar to 'P260'
# - 'P20' might be similar to 'P270'
# - 'P20' might be similar to 'P280'
# - 'P20' might be similar to 'P290'
# - 'P20' might be similar to 'P320'
# - 'P20' might be similar to 'P420'
# - 'P20' might be similar to 'P520'
# - 'P20' might be similar to 'P620'
# - 'P20' might be similar to 'P720'
# - 'P20' might be similar to 'P820'
# - 'P20' might be similar to 'P920'
# - 'P21' might be similar to 'P121'
# - 'P21' might be similar to 'P201'
# - 'P21' might be similar to 'P210'
# - 'P21' might be similar to 'P211'
# - 'P21' might be similar to 'P212'
# - 'P21' might be similar to 'P213'
# - 'P21' might be similar to 'P214'
# - 'P21' might be similar to 'P215'
# - 'P21' might be similar to 'P216'
# - 'P21' might be similar to 'P217'
# - 'P21' might be similar to 'P218'
# - 'P21' might be similar to 'P219'
# - 'P21' might be similar to 'P221'
# - 'P21' might be similar to 'P231'
# - 'P21' might be similar to 'P241'
# - 'P21' might be similar to 'P251'
# - 'P21' might be similar to 'P261'
# - 'P21' might be similar to 'P271'
# - 'P21' might be similar to 'P281'
# - 'P21' might be similar to 'P291'
# - 'P21' might be similar to 'P321'
# - 'P21' might be similar to 'P421'
# - 'P21' might be similar to 'P521'
# - 'P21' might be similar to 'P621'
# - 'P21' might be similar to 'P721'
# - 'P21' might be similar to 'P821'
# - 'P21' might be similar to 'P921'
# - 'P22' might be similar to 'P122'
# - 'P22' might be similar to 'P202'
# - 'P22' might be similar to 'P212'
# - 'P22' might be similar to 'P220'
# - 'P22' might be similar to 'P221'
# - 'P22' might be similar to 'P222'
# - 'P22' might be similar to 'P223'
# - 'P22' might be similar to 'P224'
# - 'P22' might be similar to 'P225'
# - 'P22' might be similar to 'P226'
# - 'P22' might be similar to 'P227'
# - 'P22' might be similar to 'P228'
# - 'P22' might be similar to 'P229'
# - 'P22' might be similar to 'P232'
# - 'P22' might be similar to 'P242'
# - 'P22' might be similar to 'P252'
# - 'P22' might be similar to 'P262'
# - 'P22' might be similar to 'P272'
# - 'P22' might be similar to 'P282'
# - 'P22' might be similar to 'P292'
# - 'P22' might be similar to 'P322'
# - 'P22' might be similar to 'P422'
# - 'P22' might be similar to 'P522'
# - 'P22' might be similar to 'P622'
# - 'P22' might be similar to 'P722'
# - 'P22' might be similar to 'P822'
# - 'P22' might be similar to 'P922'
# - 'P23' might be similar to 'P123'
# - 'P23' might be similar to 'P203'
# - 'P23' might be similar to 'P213'
# - 'P23' might be similar to 'P223'
# - 'P23' might be similar to 'P230'
# - 'P23' might be similar to 'P231'
# - 'P23' might be similar to 'P232'
# - 'P23' might be similar to 'P233'
# - 'P23' might be similar to 'P234'
# - 'P23' might be similar to 'P235'
# - 'P23' might be similar to 'P236'
# - 'P23' might be similar to 'P237'
# - 'P23' might be similar to 'P238'
# - 'P23' might be similar to 'P239'
# - 'P23' might be similar to 'P243'
# - 'P23' might be similar to 'P253'
# - 'P23' might be similar to 'P263'
# - 'P23' might be similar to 'P273'
# - 'P23' might be similar to 'P283'
# - 'P23' might be similar to 'P293'
# - 'P23' might be similar to 'P323'
# - 'P23' might be similar to 'P423'
# - 'P23' might be similar to 'P523'
# - 'P23' might be similar to 'P623'
# - 'P23' might be similar to 'P723'
# - 'P23' might be similar to 'P823'
# - 'P23' might be similar to 'P923'
# - 'P24' might be similar to 'P124'
# - 'P24' might be similar to 'P204'
# - 'P24' might be similar to 'P214'
# - 'P24' might be similar to 'P224'
# - 'P24' might be similar to 'P234'
# - 'P24' might be similar to 'P240'
# - 'P24' might be similar to 'P241'
# - 'P24' might be similar to 'P242'
# - 'P24' might be similar to 'P243'
# - 'P24' might be similar to 'P244'
# - 'P24' might be similar to 'P245'
# - 'P24' might be similar to 'P246'
# - 'P24' might be similar to 'P247'
# - 'P24' might be similar to 'P248'
# - 'P24' might be similar to 'P249'
# - 'P24' might be similar to 'P254'
# - 'P24' might be similar to 'P264'
# - 'P24' might be similar to 'P274'
# - 'P24' might be similar to 'P284'
# - 'P24' might be similar to 'P294'
# - 'P24' might be similar to 'P324'
# - 'P24' might be similar to 'P424'
# - 'P24' might be similar to 'P524'
# - 'P24' might be similar to 'P624'
# - 'P24' might be similar to 'P724'
# - 'P24' might be similar to 'P824'
# - 'P24' might be similar to 'P924'
# - 'P25' might be similar to 'P125'
# - 'P25' might be similar to 'P205'
# - 'P25' might be similar to 'P215'
# - 'P25' might be similar to 'P225'
# - 'P25' might be similar to 'P235'
# - 'P25' might be similar to 'P245'
# - 'P25' might be similar to 'P250'
# - 'P25' might be similar to 'P251'
# - 'P25' might be similar to 'P252'
# - 'P25' might be similar to 'P253'
# - 'P25' might be similar to 'P254'
# - 'P25' might be similar to 'P255'
# - 'P25' might be similar to 'P256'
# - 'P25' might be similar to 'P257'
# - 'P25' might be similar to 'P258'
# - 'P25' might be similar to 'P259'
# - 'P25' might be similar to 'P265'
# - 'P25' might be similar to 'P275'
# - 'P25' might be similar to 'P285'
# - 'P25' might be similar to 'P295'
# - 'P25' might be similar to 'P325'
# - 'P25' might be similar to 'P425'
# - 'P25' might be similar to 'P525'
# - 'P25' might be similar to 'P625'
# - 'P25' might be similar to 'P725'
# - 'P25' might be similar to 'P825'
# - 'P25' might be similar to 'P925'
# - 'P26' might be similar to 'P126'
# - 'P26' might be similar to 'P206'
# - 'P26' might be similar to 'P216'
# - 'P26' might be similar to 'P226'
# - 'P26' might be similar to 'P236'
# - 'P26' might be similar to 'P246'
# - 'P26' might be similar to 'P256'
# - 'P26' might be similar to 'P260'
# - 'P26' might be similar to 'P261'
# - 'P26' might be similar to 'P262'
# - 'P26' might be similar to 'P263'
# - 'P26' might be similar to 'P264'
# - 'P26' might be similar to 'P265'
# - 'P26' might be similar to 'P266'
# - 'P26' might be similar to 'P267'
# - 'P26' might be similar to 'P268'
# - 'P26' might be similar to 'P269'
# - 'P26' might be similar to 'P276'
# - 'P26' might be similar to 'P286'
# - 'P26' might be similar to 'P296'
# - 'P26' might be similar to 'P326'
# - 'P26' might be similar to 'P426'
# - 'P26' might be similar to 'P526'
# - 'P26' might be similar to 'P626'
# - 'P26' might be similar to 'P726'
# - 'P26' might be similar to 'P826'
# - 'P26' might be similar to 'P926'
# - 'P27' might be similar to 'P127'
# - 'P27' might be similar to 'P207'
# - 'P27' might be similar to 'P217'
# - 'P27' might be similar to 'P227'
# - 'P27' might be similar to 'P237'
# - 'P27' might be similar to 'P247'
# - 'P27' might be similar to 'P257'
# - 'P27' might be similar to 'P267'
# - 'P27' might be similar to 'P270'
# - 'P27' might be similar to 'P271'
# - 'P27' might be similar to 'P272'
# - 'P27' might be similar to 'P273'
# - 'P27' might be similar to 'P274'
# - 'P27' might be similar to 'P275'
# - 'P27' might be similar to 'P276'
# - 'P27' might be similar to 'P277'
# - 'P27' might be similar to 'P278'
# - 'P27' might be similar to 'P279'
# - 'P27' might be similar to 'P287'
# - 'P27' might be similar to 'P297'
# - 'P27' might be similar to 'P327'
# - 'P27' might be similar to 'P427'
# - 'P27' might be similar to 'P527'
# - 'P27' might be similar to 'P627'
# - 'P27' might be similar to 'P727'
# - 'P27' might be similar to 'P827'
# - 'P27' might be similar to 'P927'
# - 'P28' might be similar to 'P128'
# - 'P28' might be similar to 'P208'
# - 'P28' might be similar to 'P218'
# - 'P28' might be similar to 'P228'
# - 'P28' might be similar to 'P238'
# - 'P28' might be similar to 'P248'
# - 'P28' might be similar to 'P258'
# - 'P28' might be similar to 'P268'
# - 'P28' might be similar to 'P278'
# - 'P28' might be similar to 'P280'
# - 'P28' might be similar to 'P281'
# - 'P28' might be similar to 'P282'
# - 'P28' might be similar to 'P283'
# - 'P28' might be similar to 'P284'
# - 'P28' might be similar to 'P285'
# - 'P28' might be similar to 'P286'
# - 'P28' might be similar to 'P287'
# - 'P28' might be similar to 'P288'
# - 'P28' might be similar to 'P289'
# - 'P28' might be similar to 'P298'
# - 'P28' might be similar to 'P328'
# - 'P28' might be similar to 'P428'
# - 'P28' might be similar to 'P528'
# - 'P28' might be similar to 'P628'
# - 'P28' might be similar to 'P728'
# - 'P28' might be similar to 'P828'
# - 'P28' might be similar to 'P928'
# - 'P29' might be similar to 'P129'
# - 'P29' might be similar to 'P209'
# - 'P29' might be similar to 'P219'
# - 'P29' might be similar to 'P229'
# - 'P29' might be similar to 'P239'
# - 'P29' might be similar to 'P249'
# - 'P29' might be similar to 'P259'
# - 'P29' might be similar to 'P269'
# - 'P29' might be similar to 'P279'
# - 'P29' might be similar to 'P289'
# - 'P29' might be similar to 'P290'
# - 'P29' might be similar to 'P291'
# - 'P29' might be similar to 'P292'
# - 'P29' might be similar to 'P293'
# - 'P29' might be similar to 'P294'
# - 'P29' might be similar to 'P295'
# - 'P29' might be similar to 'P296'
# - 'P29' might be similar to 'P297'
# - 'P29' might be similar to 'P298'
# - 'P29' might be similar to 'P299'
# - 'P29' might be similar to 'P329'
# - 'P29' might be similar to 'P429'
# - 'P29' might be similar to 'P529'
# - 'P29' might be similar to 'P629'
# - 'P29' might be similar to 'P729'
# - 'P29' might be similar to 'P829'
# - 'P29' might be similar to 'P929'
# - 'P30' might be similar to 'P130'
# - 'P30' might be similar to 'P230'
# - 'P30' might be similar to 'P300'
# - 'P30' might be similar to 'P301'
# - 'P30' might be similar to 'P302'
# - 'P30' might be similar to 'P303'
# - 'P30' might be similar to 'P304'
# - 'P30' might be similar to 'P305'
# - 'P30' might be similar to 'P306'
# - 'P30' might be similar to 'P307'
# - 'P30' might be similar to 'P308'
# - 'P30' might be similar to 'P309'
# - 'P30' might be similar to 'P310'
# - 'P30' might be similar to 'P320'
# - 'P30' might be similar to 'P330'
# - 'P30' might be similar to 'P340'
# - 'P30' might be similar to 'P350'
# - 'P30' might be similar to 'P360'
# - 'P30' might be similar to 'P370'
# - 'P30' might be similar to 'P380'
# - 'P30' might be similar to 'P390'
# - 'P30' might be similar to 'P430'
# - 'P30' might be similar to 'P530'
# - 'P30' might be similar to 'P630'
# - 'P30' might be similar to 'P730'
# - 'P30' might be similar to 'P830'
# - 'P30' might be similar to 'P930'
# - 'P31' might be similar to 'P131'
# - 'P31' might be similar to 'P231'
# - 'P31' might be similar to 'P301'
# - 'P31' might be similar to 'P310'
# - 'P31' might be similar to 'P311'
# - 'P31' might be similar to 'P312'
# - 'P31' might be similar to 'P313'
# - 'P31' might be similar to 'P314'
# - 'P31' might be similar to 'P315'
# - 'P31' might be similar to 'P316'
# - 'P31' might be similar to 'P317'
# - 'P31' might be similar to 'P318'
# - 'P31' might be similar to 'P319'
# - 'P31' might be similar to 'P321'
# - 'P31' might be similar to 'P331'
# - 'P31' might be similar to 'P341'
# - 'P31' might be similar to 'P351'
# - 'P31' might be similar to 'P361'
# - 'P31' might be similar to 'P371'
# - 'P31' might be similar to 'P381'
# - 'P31' might be similar to 'P391'
# - 'P31' might be similar to 'P431'
# - 'P31' might be similar to 'P531'
# - 'P31' might be similar to 'P631'
# - 'P31' might be similar to 'P731'
# - 'P31' might be similar to 'P831'
# - 'P31' might be similar to 'P931'
# - 'P32' might be similar to 'P132'
# - 'P32' might be similar to 'P232'
# - 'P32' might be similar to 'P302'
# - 'P32' might be similar to 'P312'
# - 'P32' might be similar to 'P320'
# - 'P32' might be similar to 'P321'
# - 'P32' might be similar to 'P322'
# - 'P32' might be similar to 'P323'
# - 'P32' might be similar to 'P324'
# - 'P32' might be similar to 'P325'
# - 'P32' might be similar to 'P326'
# - 'P32' might be similar to 'P327'
# - 'P32' might be similar to 'P328'
# - 'P32' might be similar to 'P329'
# - 'P32' might be similar to 'P332'
# - 'P32' might be similar to 'P342'
# - 'P32' might be similar to 'P352'
# - 'P32' might be similar to 'P362'
# - 'P32' might be similar to 'P372'
# - 'P32' might be similar to 'P382'
# - 'P32' might be similar to 'P392'
# - 'P32' might be similar to 'P432'
# - 'P32' might be similar to 'P532'
# - 'P32' might be similar to 'P632'
# - 'P32' might be similar to 'P732'
# - 'P32' might be similar to 'P832'
# - 'P32' might be similar to 'P932'
# - 'P33' might be similar to 'P133'
# - 'P33' might be similar to 'P233'
# - 'P33' might be similar to 'P303'
# - 'P33' might be similar to 'P313'
# - 'P33' might be similar to 'P323'
# - 'P33' might be similar to 'P330'
# - 'P33' might be similar to 'P331'
# - 'P33' might be similar to 'P332'
# - 'P33' might be similar to 'P333'
# - 'P33' might be similar to 'P334'
# - 'P33' might be similar to 'P335'
# - 'P33' might be similar to 'P336'
# - 'P33' might be similar to 'P337'
# - 'P33' might be similar to 'P338'
# - 'P33' might be similar to 'P339'
# - 'P33' might be similar to 'P343'
# - 'P33' might be similar to 'P353'
# - 'P33' might be similar to 'P363'
# - 'P33' might be similar to 'P373'
# - 'P33' might be similar to 'P383'
# - 'P33' might be similar to 'P393'
# - 'P33' might be similar to 'P433'
# - 'P33' might be similar to 'P533'
# - 'P33' might be similar to 'P633'
# - 'P33' might be similar to 'P733'
# - 'P33' might be similar to 'P833'
# - 'P33' might be similar to 'P933'
# - 'P34' might be similar to 'P134'
# - 'P34' might be similar to 'P234'
# - 'P34' might be similar to 'P304'
# - 'P34' might be similar to 'P314'
# - 'P34' might be similar to 'P324'
# - 'P34' might be similar to 'P334'
# - 'P34' might be similar to 'P340'
# - 'P34' might be similar to 'P341'
# - 'P34' might be similar to 'P342'
# - 'P34' might be similar to 'P343'
# - 'P34' might be similar to 'P344'
# - 'P34' might be similar to 'P345'
# - 'P34' might be similar to 'P346'
# - 'P34' might be similar to 'P347'
# - 'P34' might be similar to 'P348'
# - 'P34' might be similar to 'P349'
# - 'P34' might be similar to 'P354'
# - 'P34' might be similar to 'P364'
# - 'P34' might be similar to 'P374'
# - 'P34' might be similar to 'P384'
# - 'P34' might be similar to 'P394'
# - 'P34' might be similar to 'P434'
# - 'P34' might be similar to 'P534'
# - 'P34' might be similar to 'P634'
# - 'P34' might be similar to 'P734'
# - 'P34' might be similar to 'P834'
# - 'P34' might be similar to 'P934'
# - 'P35' might be similar to 'P135'
# - 'P35' might be similar to 'P235'
# - 'P35' might be similar to 'P305'
# - 'P35' might be similar to 'P315'
# - 'P35' might be similar to 'P325'
# - 'P35' might be similar to 'P335'
# - 'P35' might be similar to 'P345'
# - 'P35' might be similar to 'P350'
# - 'P35' might be similar to 'P351'
# - 'P35' might be similar to 'P352'
# - 'P35' might be similar to 'P353'
# - 'P35' might be similar to 'P354'
# - 'P35' might be similar to 'P355'
# - 'P35' might be similar to 'P356'
# - 'P35' might be similar to 'P357'
# - 'P35' might be similar to 'P358'
# - 'P35' might be similar to 'P359'
# - 'P35' might be similar to 'P365'
# - 'P35' might be similar to 'P375'
# - 'P35' might be similar to 'P385'
# - 'P35' might be similar to 'P395'
# - 'P35' might be similar to 'P435'
# - 'P35' might be similar to 'P535'
# - 'P35' might be similar to 'P635'
# - 'P35' might be similar to 'P735'
# - 'P35' might be similar to 'P835'
# - 'P35' might be similar to 'P935'
# - 'P36' might be similar to 'P136'
# - 'P36' might be similar to 'P236'
# - 'P36' might be similar to 'P306'
# - 'P36' might be similar to 'P316'
# - 'P36' might be similar to 'P326'
# - 'P36' might be similar to 'P336'
# - 'P36' might be similar to 'P346'
# - 'P36' might be similar to 'P356'
# - 'P36' might be similar to 'P360'
# - 'P36' might be similar to 'P361'
# - 'P36' might be similar to 'P362'
# - 'P36' might be similar to 'P363'
# - 'P36' might be similar to 'P364'
# - 'P36' might be similar to 'P365'
# - 'P36' might be similar to 'P366'
# - 'P36' might be similar to 'P367'
# - 'P36' might be similar to 'P368'
# - 'P36' might be similar to 'P369'
# - 'P36' might be similar to 'P376'
# - 'P36' might be similar to 'P386'
# - 'P36' might be similar to 'P396'
# - 'P36' might be similar to 'P436'
# - 'P36' might be similar to 'P536'
# - 'P36' might be similar to 'P636'
# - 'P36' might be similar to 'P736'
# - 'P36' might be similar to 'P836'
# - 'P36' might be similar to 'P936'
# - 'P37' might be similar to 'P137'
# - 'P37' might be similar to 'P237'
# - 'P37' might be similar to 'P307'
# - 'P37' might be similar to 'P317'
# - 'P37' might be similar to 'P327'
# - 'P37' might be similar to 'P337'
# - 'P37' might be similar to 'P347'
# - 'P37' might be similar to 'P357'
# - 'P37' might be similar to 'P367'
# - 'P37' might be similar to 'P370'
# - 'P37' might be similar to 'P371'
# - 'P37' might be similar to 'P372'
# - 'P37' might be similar to 'P373'
# - 'P37' might be similar to 'P374'
# - 'P37' might be similar to 'P375'
# - 'P37' might be similar to 'P376'
# - 'P37' might be similar to 'P377'
# - 'P37' might be similar to 'P378'
# - 'P37' might be similar to 'P379'
# - 'P37' might be similar to 'P387'
# - 'P37' might be similar to 'P397'
# - 'P37' might be similar to 'P437'
# - 'P37' might be similar to 'P537'
# - 'P37' might be similar to 'P637'
# - 'P37' might be similar to 'P737'
# - 'P37' might be similar to 'P837'
# - 'P37' might be similar to 'P937'
# - 'P38' might be similar to 'P138'
# - 'P38' might be similar to 'P238'
# - 'P38' might be similar to 'P308'
# - 'P38' might be similar to 'P318'
# - 'P38' might be similar to 'P328'
# - 'P38' might be similar to 'P338'
# - 'P38' might be similar to 'P348'
# - 'P38' might be similar to 'P358'
# - 'P38' might be similar to 'P368'
# - 'P38' might be similar to 'P378'
# - 'P38' might be similar to 'P380'
# - 'P38' might be similar to 'P381'
# - 'P38' might be similar to 'P382'
# - 'P38' might be similar to 'P383'
# - 'P38' might be similar to 'P384'
# - 'P38' might be similar to 'P385'
# - 'P38' might be similar to 'P386'
# - 'P38' might be similar to 'P387'
# - 'P38' might be similar to 'P388'
# - 'P38' might be similar to 'P389'
# - 'P38' might be similar to 'P398'
# - 'P38' might be similar to 'P438'
# - 'P38' might be similar to 'P538'
# - 'P38' might be similar to 'P638'
# - 'P38' might be similar to 'P738'
# - 'P38' might be similar to 'P838'
# - 'P38' might be similar to 'P938'
# - 'P39' might be similar to 'P139'
# - 'P39' might be similar to 'P239'
# - 'P39' might be similar to 'P309'
# - 'P39' might be similar to 'P319'
# - 'P39' might be similar to 'P329'
# - 'P39' might be similar to 'P339'
# - 'P39' might be similar to 'P349'
# - 'P39' might be similar to 'P359'
# - 'P39' might be similar to 'P369'
# - 'P39' might be similar to 'P379'
# - 'P39' might be similar to 'P389'
# - 'P39' might be similar to 'P390'
# - 'P39' might be similar to 'P391'
# - 'P39' might be similar to 'P392'
# - 'P39' might be similar to 'P393'
# - 'P39' might be similar to 'P394'
# - 'P39' might be similar to 'P395'
# - 'P39' might be similar to 'P396'
# - 'P39' might be similar to 'P397'
# - 'P39' might be similar to 'P398'
# - 'P39' might be similar to 'P399'
# - 'P39' might be similar to 'P439'
# - 'P39' might be similar to 'P539'
# - 'P39' might be similar to 'P639'
# - 'P39' might be similar to 'P739'
# - 'P39' might be similar to 'P839'
# - 'P39' might be similar to 'P939'
# - 'P40' might be similar to 'P140'
# - 'P40' might be similar to 'P240'
# - 'P40' might be similar to 'P340'
# - 'P40' might be similar to 'P400'
# - 'P40' might be similar to 'P401'
# - 'P40' might be similar to 'P402'
# - 'P40' might be similar to 'P403'
# - 'P40' might be similar to 'P404'
# - 'P40' might be similar to 'P405'
# - 'P40' might be similar to 'P406'
# - 'P40' might be similar to 'P407'
# - 'P40' might be similar to 'P408'
# - 'P40' might be similar to 'P409'
# - 'P40' might be similar to 'P410'
# - 'P40' might be similar to 'P420'
# - 'P40' might be similar to 'P430'
# - 'P40' might be similar to 'P440'
# - 'P40' might be similar to 'P450'
# - 'P40' might be similar to 'P460'
# - 'P40' might be similar to 'P470'
# - 'P40' might be similar to 'P480'
# - 'P40' might be similar to 'P490'
# - 'P40' might be similar to 'P540'
# - 'P40' might be similar to 'P640'
# - 'P40' might be similar to 'P740'
# - 'P40' might be similar to 'P840'
# - 'P40' might be similar to 'P940'
# - 'P41' might be similar to 'P141'
# - 'P41' might be similar to 'P241'
# - 'P41' might be similar to 'P341'
# - 'P41' might be similar to 'P401'
# - 'P41' might be similar to 'P410'
# - 'P41' might be similar to 'P411'
# - 'P41' might be similar to 'P412'
# - 'P41' might be similar to 'P413'
# - 'P41' might be similar to 'P414'
# - 'P41' might be similar to 'P415'
# - 'P41' might be similar to 'P416'
# - 'P41' might be similar to 'P417'
# - 'P41' might be similar to 'P418'
# - 'P41' might be similar to 'P419'
# - 'P41' might be similar to 'P421'
# - 'P41' might be similar to 'P431'
# - 'P41' might be similar to 'P441'
# - 'P41' might be similar to 'P451'
# - 'P41' might be similar to 'P461'
# - 'P41' might be similar to 'P471'
# - 'P41' might be similar to 'P481'
# - 'P41' might be similar to 'P491'
# - 'P41' might be similar to 'P541'
# - 'P41' might be similar to 'P641'
# - 'P41' might be similar to 'P741'
# - 'P41' might be similar to 'P841'
# - 'P41' might be similar to 'P941'
# - 'P42' might be similar to 'P142'
# - 'P42' might be similar to 'P242'
# - 'P42' might be similar to 'P342'
# - 'P42' might be similar to 'P402'
# - 'P42' might be similar to 'P412'
# - 'P42' might be similar to 'P420'
# - 'P42' might be similar to 'P421'
# - 'P42' might be similar to 'P422'
# - 'P42' might be similar to 'P423'
# - 'P42' might be similar to 'P424'
# - 'P42' might be similar to 'P425'
# - 'P42' might be similar to 'P426'
# - 'P42' might be similar to 'P427'
# - 'P42' might be similar to 'P428'
# - 'P42' might be similar to 'P429'
# - 'P42' might be similar to 'P432'
# - 'P42' might be similar to 'P442'
# - 'P42' might be similar to 'P452'
# - 'P42' might be similar to 'P462'
# - 'P42' might be similar to 'P472'
# - 'P42' might be similar to 'P482'
# - 'P42' might be similar to 'P492'
# - 'P42' might be similar to 'P542'
# - 'P42' might be similar to 'P642'
# - 'P42' might be similar to 'P742'
# - 'P42' might be similar to 'P842'
# - 'P42' might be similar to 'P942'
# - 'P43' might be similar to 'P143'
# - 'P43' might be similar to 'P243'
# - 'P43' might be similar to 'P343'
# - 'P43' might be similar to 'P403'
# - 'P43' might be similar to 'P413'
# - 'P43' might be similar to 'P423'
# - 'P43' might be similar to 'P430'
# - 'P43' might be similar to 'P431'
# - 'P43' might be similar to 'P432'
# - 'P43' might be similar to 'P433'
# - 'P43' might be similar to 'P434'
# - 'P43' might be similar to 'P435'
# - 'P43' might be similar to 'P436'
# - 'P43' might be similar to 'P437'
# - 'P43' might be similar to 'P438'
# - 'P43' might be similar to 'P439'
# - 'P43' might be similar to 'P443'
# - 'P43' might be similar to 'P453'
# - 'P43' might be similar to 'P463'
# - 'P43' might be similar to 'P473'
# - 'P43' might be similar to 'P483'
# - 'P43' might be similar to 'P493'
# - 'P43' might be similar to 'P543'
# - 'P43' might be similar to 'P643'
# - 'P43' might be similar to 'P743'
# - 'P43' might be similar to 'P843'
# - 'P43' might be similar to 'P943'
# - 'P44' might be similar to 'P144'
# - 'P44' might be similar to 'P244'
# - 'P44' might be similar to 'P344'
# - 'P44' might be similar to 'P404'
# - 'P44' might be similar to 'P414'
# - 'P44' might be similar to 'P424'
# - 'P44' might be similar to 'P434'
# - 'P44' might be similar to 'P440'
# - 'P44' might be similar to 'P441'
# - 'P44' might be similar to 'P442'
# - 'P44' might be similar to 'P443'
# - 'P44' might be similar to 'P444'
# - 'P44' might be similar to 'P445'
# - 'P44' might be similar to 'P446'
# - 'P44' might be similar to 'P447'
# - 'P44' might be similar to 'P448'
# - 'P44' might be similar to 'P449'
# - 'P44' might be similar to 'P454'
# - 'P44' might be similar to 'P464'
# - 'P44' might be similar to 'P474'
# - 'P44' might be similar to 'P484'
# - 'P44' might be similar to 'P494'
# - 'P44' might be similar to 'P544'
# - 'P44' might be similar to 'P644'
# - 'P44' might be similar to 'P744'
# - 'P44' might be similar to 'P844'
# - 'P44' might be similar to 'P944'
# - 'P45' might be similar to 'P145'
# - 'P45' might be similar to 'P245'
# - 'P45' might be similar to 'P345'
# - 'P45' might be similar to 'P405'
# - 'P45' might be similar to 'P415'
# - 'P45' might be similar to 'P425'
# - 'P45' might be similar to 'P435'
# - 'P45' might be similar to 'P445'
# - 'P45' might be similar to 'P450'
# - 'P45' might be similar to 'P451'
# - 'P45' might be similar to 'P452'
# - 'P45' might be similar to 'P453'
# - 'P45' might be similar to 'P454'
# - 'P45' might be similar to 'P455'
# - 'P45' might be similar to 'P456'
# - 'P45' might be similar to 'P457'
# - 'P45' might be similar to 'P458'
# - 'P45' might be similar to 'P459'
# - 'P45' might be similar to 'P465'
# - 'P45' might be similar to 'P475'
# - 'P45' might be similar to 'P485'
# - 'P45' might be similar to 'P495'
# - 'P45' might be similar to 'P545'
# - 'P45' might be similar to 'P645'
# - 'P45' might be similar to 'P745'
# - 'P45' might be similar to 'P845'
# - 'P45' might be similar to 'P945'
# - 'P46' might be similar to 'P146'
# - 'P46' might be similar to 'P246'
# - 'P46' might be similar to 'P346'
# - 'P46' might be similar to 'P406'
# - 'P46' might be similar to 'P416'
# - 'P46' might be similar to 'P426'
# - 'P46' might be similar to 'P436'
# - 'P46' might be similar to 'P446'
# - 'P46' might be similar to 'P456'
# - 'P46' might be similar to 'P460'
# - 'P46' might be similar to 'P461'
# - 'P46' might be similar to 'P462'
# - 'P46' might be similar to 'P463'
# - 'P46' might be similar to 'P464'
# - 'P46' might be similar to 'P465'
# - 'P46' might be similar to 'P466'
# - 'P46' might be similar to 'P467'
# - 'P46' might be similar to 'P468'
# - 'P46' might be similar to 'P469'
# - 'P46' might be similar to 'P476'
# - 'P46' might be similar to 'P486'
# - 'P46' might be similar to 'P496'
# - 'P46' might be similar to 'P546'
# - 'P46' might be similar to 'P646'
# - 'P46' might be similar to 'P746'
# - 'P46' might be similar to 'P846'
# - 'P46' might be similar to 'P946'
# - 'P47' might be similar to 'P147'
# - 'P47' might be similar to 'P247'
# - 'P47' might be similar to 'P347'
# - 'P47' might be similar to 'P407'
# - 'P47' might be similar to 'P417'
# - 'P47' might be similar to 'P427'
# - 'P47' might be similar to 'P437'
# - 'P47' might be similar to 'P447'
# - 'P47' might be similar to 'P457'
# - 'P47' might be similar to 'P467'
# - 'P47' might be similar to 'P470'
# - 'P47' might be similar to 'P471'
# - 'P47' might be similar to 'P472'
# - 'P47' might be similar to 'P473'
# - 'P47' might be similar to 'P474'
# - 'P47' might be similar to 'P475'
# - 'P47' might be similar to 'P476'
# - 'P47' might be similar to 'P477'
# - 'P47' might be similar to 'P478'
# - 'P47' might be similar to 'P479'
# - 'P47' might be similar to 'P487'
# - 'P47' might be similar to 'P497'
# - 'P47' might be similar to 'P547'
# - 'P47' might be similar to 'P647'
# - 'P47' might be similar to 'P747'
# - 'P47' might be similar to 'P847'
# - 'P47' might be similar to 'P947'
# - 'P48' might be similar to 'P148'
# - 'P48' might be similar to 'P248'
# - 'P48' might be similar to 'P348'
# - 'P48' might be similar to 'P408'
# - 'P48' might be similar to 'P418'
# - 'P48' might be similar to 'P428'
# - 'P48' might be similar to 'P438'
# - 'P48' might be similar to 'P448'
# - 'P48' might be similar to 'P458'
# - 'P48' might be similar to 'P468'
# - 'P48' might be similar to 'P478'
# - 'P48' might be similar to 'P480'
# - 'P48' might be similar to 'P481'
# - 'P48' might be similar to 'P482'
# - 'P48' might be similar to 'P483'
# - 'P48' might be similar to 'P484'
# - 'P48' might be similar to 'P485'
# - 'P48' might be similar to 'P486'
# - 'P48' might be similar to 'P487'
# - 'P48' might be similar to 'P488'
# - 'P48' might be similar to 'P489'
# - 'P48' might be similar to 'P498'
# - 'P48' might be similar to 'P548'
# - 'P48' might be similar to 'P648'
# - 'P48' might be similar to 'P748'
# - 'P48' might be similar to 'P848'
# - 'P48' might be similar to 'P948'
# - 'P49' might be similar to 'P149'
# - 'P49' might be similar to 'P249'
# - 'P49' might be similar to 'P349'
# - 'P49' might be similar to 'P409'
# - 'P49' might be similar to 'P419'
# - 'P49' might be similar to 'P429'
# - 'P49' might be similar to 'P439'
# - 'P49' might be similar to 'P449'
# - 'P49' might be similar to 'P459'
# - 'P49' might be similar to 'P469'
# - 'P49' might be similar to 'P479'
# - 'P49' might be similar to 'P489'
# - 'P49' might be similar to 'P490'
# - 'P49' might be similar to 'P491'
# - 'P49' might be similar to 'P492'
# - 'P49' might be similar to 'P493'
# - 'P49' might be similar to 'P494'
# - 'P49' might be similar to 'P495'
# - 'P49' might be similar to 'P496'
# - 'P49' might be similar to 'P497'
# - 'P49' might be similar to 'P498'
# - 'P49' might be similar to 'P499'
# - 'P49' might be similar to 'P549'
# - 'P49' might be similar to 'P649'
# - 'P49' might be similar to 'P749'
# - 'P49' might be similar to 'P849'
# - 'P49' might be similar to 'P949'
# - 'P50' might be similar to 'P150'
# - 'P50' might be similar to 'P250'
# - 'P50' might be similar to 'P350'
# - 'P50' might be similar to 'P450'
# - 'P50' might be similar to 'P500'
# - 'P50' might be similar to 'P501'
# - 'P50' might be similar to 'P502'
# - 'P50' might be similar to 'P503'
# - 'P50' might be similar to 'P504'
# - 'P50' might be similar to 'P505'
# - 'P50' might be similar to 'P506'
# - 'P50' might be similar to 'P507'
# - 'P50' might be similar to 'P508'
# - 'P50' might be similar to 'P509'
# - 'P50' might be similar to 'P510'
# - 'P50' might be similar to 'P520'
# - 'P50' might be similar to 'P530'
# - 'P50' might be similar to 'P540'
# - 'P50' might be similar to 'P550'
# - 'P50' might be similar to 'P560'
# - 'P50' might be similar to 'P570'
# - 'P50' might be similar to 'P580'
# - 'P50' might be similar to 'P590'
# - 'P50' might be similar to 'P650'
# - 'P50' might be similar to 'P750'
# - 'P50' might be similar to 'P850'
# - 'P50' might be similar to 'P950'
# - 'P51' might be similar to 'P151'
# - 'P51' might be similar to 'P251'
# - 'P51' might be similar to 'P351'
# - 'P51' might be similar to 'P451'
# - 'P51' might be similar to 'P501'
# - 'P51' might be similar to 'P510'
# - 'P51' might be similar to 'P511'
# - 'P51' might be similar to 'P512'
# - 'P51' might be similar to 'P513'
# - 'P51' might be similar to 'P514'
# - 'P51' might be similar to 'P515'
# - 'P51' might be similar to 'P516'
# - 'P51' might be similar to 'P517'
# - 'P51' might be similar to 'P518'
# - 'P51' might be similar to 'P519'
# - 'P51' might be similar to 'P521'
# - 'P51' might be similar to 'P531'
# - 'P51' might be similar to 'P541'
# - 'P51' might be similar to 'P551'
# - 'P51' might be similar to 'P561'
# - 'P51' might be similar to 'P571'
# - 'P51' might be similar to 'P581'
# - 'P51' might be similar to 'P591'
# - 'P51' might be similar to 'P651'
# - 'P51' might be similar to 'P751'
# - 'P51' might be similar to 'P851'
# - 'P51' might be similar to 'P951'
# - 'P52' might be similar to 'P152'
# - 'P52' might be similar to 'P252'
# - 'P52' might be similar to 'P352'
# - 'P52' might be similar to 'P452'
# - 'P52' might be similar to 'P502'
# - 'P52' might be similar to 'P512'
# - 'P52' might be similar to 'P520'
# - 'P52' might be similar to 'P521'
# - 'P52' might be similar to 'P522'
# - 'P52' might be similar to 'P523'
# - 'P52' might be similar to 'P524'
# - 'P52' might be similar to 'P525'
# - 'P52' might be similar to 'P526'
# - 'P52' might be similar to 'P527'
# - 'P52' might be similar to 'P528'
# - 'P52' might be similar to 'P529'
# - 'P52' might be similar to 'P532'
# - 'P52' might be similar to 'P542'
# - 'P52' might be similar to 'P552'
# - 'P52' might be similar to 'P562'
# - 'P52' might be similar to 'P572'
# - 'P52' might be similar to 'P582'
# - 'P52' might be similar to 'P592'
# - 'P52' might be similar to 'P652'
# - 'P52' might be similar to 'P752'
# - 'P52' might be similar to 'P852'
# - 'P52' might be similar to 'P952'
# - 'P53' might be similar to 'P153'
# - 'P53' might be similar to 'P253'
# - 'P53' might be similar to 'P353'
# - 'P53' might be similar to 'P453'
# - 'P53' might be similar to 'P503'
# - 'P53' might be similar to 'P513'
# - 'P53' might be similar to 'P523'
# - 'P53' might be similar to 'P530'
# - 'P53' might be similar to 'P531'
# - 'P53' might be similar to 'P532'
# - 'P53' might be similar to 'P533'
# - 'P53' might be similar to 'P534'
# - 'P53' might be similar to 'P535'
# - 'P53' might be similar to 'P536'
# - 'P53' might be similar to 'P537'
# - 'P53' might be similar to 'P538'
# - 'P53' might be similar to 'P539'
# - 'P53' might be similar to 'P543'
# - 'P53' might be similar to 'P553'
# - 'P53' might be similar to 'P563'
# - 'P53' might be similar to 'P573'
# - 'P53' might be similar to 'P583'
# - 'P53' might be similar to 'P593'
# - 'P53' might be similar to 'P653'
# - 'P53' might be similar to 'P753'
# - 'P53' might be similar to 'P853'
# - 'P53' might be similar to 'P953'
# - 'P54' might be similar to 'P154'
# - 'P54' might be similar to 'P254'
# - 'P54' might be similar to 'P354'
# - 'P54' might be similar to 'P454'
# - 'P54' might be similar to 'P504'
# - 'P54' might be similar to 'P514'
# - 'P54' might be similar to 'P524'
# - 'P54' might be similar to 'P534'
# - 'P54' might be similar to 'P540'
# - 'P54' might be similar to 'P541'
# - 'P54' might be similar to 'P542'
# - 'P54' might be similar to 'P543'
# - 'P54' might be similar to 'P544'
# - 'P54' might be similar to 'P545'
# - 'P54' might be similar to 'P546'
# - 'P54' might be similar to 'P547'
# - 'P54' might be similar to 'P548'
# - 'P54' might be similar to 'P549'
# - 'P54' might be similar to 'P554'
# - 'P54' might be similar to 'P564'
# - 'P54' might be similar to 'P574'
# - 'P54' might be similar to 'P584'
# - 'P54' might be similar to 'P594'
# - 'P54' might be similar to 'P654'
# - 'P54' might be similar to 'P754'
# - 'P54' might be similar to 'P854'
# - 'P54' might be similar to 'P954'
# - 'P55' might be similar to 'P155'
# - 'P55' might be similar to 'P255'
# - 'P55' might be similar to 'P355'
# - 'P55' might be similar to 'P455'
# - 'P55' might be similar to 'P505'
# - 'P55' might be similar to 'P515'
# - 'P55' might be similar to 'P525'
# - 'P55' might be similar to 'P535'
# - 'P55' might be similar to 'P545'
# - 'P55' might be similar to 'P550'
# - 'P55' might be similar to 'P551'
# - 'P55' might be similar to 'P552'
# - 'P55' might be similar to 'P553'
# - 'P55' might be similar to 'P554'
# - 'P55' might be similar to 'P555'
# - 'P55' might be similar to 'P556'
# - 'P55' might be similar to 'P557'
# - 'P55' might be similar to 'P558'
# - 'P55' might be similar to 'P559'
# - 'P55' might be similar to 'P565'
# - 'P55' might be similar to 'P575'
# - 'P55' might be similar to 'P585'
# - 'P55' might be similar to 'P595'
# - 'P55' might be similar to 'P655'
# - 'P55' might be similar to 'P755'
# - 'P55' might be similar to 'P855'
# - 'P55' might be similar to 'P955'
# - 'P56' might be similar to 'P156'
# - 'P56' might be similar to 'P256'
# - 'P56' might be similar to 'P356'
# - 'P56' might be similar to 'P456'
# - 'P56' might be similar to 'P506'
# - 'P56' might be similar to 'P516'
# - 'P56' might be similar to 'P526'
# - 'P56' might be similar to 'P536'
# - 'P56' might be similar to 'P546'
# - 'P56' might be similar to 'P556'
# - 'P56' might be similar to 'P560'
# - 'P56' might be similar to 'P561'
# - 'P56' might be similar to 'P562'
# - 'P56' might be similar to 'P563'
# - 'P56' might be similar to 'P564'
# - 'P56' might be similar to 'P565'
# - 'P56' might be similar to 'P566'
# - 'P56' might be similar to 'P567'
# - 'P56' might be similar to 'P568'
# - 'P56' might be similar to 'P569'
# - 'P56' might be similar to 'P576'
# - 'P56' might be similar to 'P586'
# - 'P56' might be similar to 'P596'
# - 'P56' might be similar to 'P656'
# - 'P56' might be similar to 'P756'
# - 'P56' might be similar to 'P856'
# - 'P56' might be similar to 'P956'
# - 'P57' might be similar to 'P157'
# - 'P57' might be similar to 'P257'
# - 'P57' might be similar to 'P357'
# - 'P57' might be similar to 'P457'
# - 'P57' might be similar to 'P507'
# - 'P57' might be similar to 'P517'
# - 'P57' might be similar to 'P527'
# - 'P57' might be similar to 'P537'
# - 'P57' might be similar to 'P547'
# - 'P57' might be similar to 'P557'
# - 'P57' might be similar to 'P567'
# - 'P57' might be similar to 'P570'
# - 'P57' might be similar to 'P571'
# - 'P57' might be similar to 'P572'
# - 'P57' might be similar to 'P573'
# - 'P57' might be similar to 'P574'
# - 'P57' might be similar to 'P575'
# - 'P57' might be similar to 'P576'
# - 'P57' might be similar to 'P577'
# - 'P57' might be similar to 'P578'
# - 'P57' might be similar to 'P579'
# - 'P57' might be similar to 'P587'
# - 'P57' might be similar to 'P597'
# - 'P57' might be similar to 'P657'
# - 'P57' might be similar to 'P757'
# - 'P57' might be similar to 'P857'
# - 'P57' might be similar to 'P957'
# - 'P58' might be similar to 'P158'
# - 'P58' might be similar to 'P258'
# - 'P58' might be similar to 'P358'
# - 'P58' might be similar to 'P458'
# - 'P58' might be similar to 'P508'
# - 'P58' might be similar to 'P518'
# - 'P58' might be similar to 'P528'
# - 'P58' might be similar to 'P538'
# - 'P58' might be similar to 'P548'
# - 'P58' might be similar to 'P558'
# - 'P58' might be similar to 'P568'
# - 'P58' might be similar to 'P578'
# - 'P58' might be similar to 'P580'
# - 'P58' might be similar to 'P581'
# - 'P58' might be similar to 'P582'
# - 'P58' might be similar to 'P583'
# - 'P58' might be similar to 'P584'
# - 'P58' might be similar to 'P585'
# - 'P58' might be similar to 'P586'
# - 'P58' might be similar to 'P587'
# - 'P58' might be similar to 'P588'
# - 'P58' might be similar to 'P589'
# - 'P58' might be similar to 'P598'
# - 'P58' might be similar to 'P658'
# - 'P58' might be similar to 'P758'
# - 'P58' might be similar to 'P858'
# - 'P58' might be similar to 'P958'
# - 'P59' might be similar to 'P159'
# - 'P59' might be similar to 'P259'
# - 'P59' might be similar to 'P359'
# - 'P59' might be similar to 'P459'
# - 'P59' might be similar to 'P509'
# - 'P59' might be similar to 'P519'
# - 'P59' might be similar to 'P529'
# - 'P59' might be similar to 'P539'
# - 'P59' might be similar to 'P549'
# - 'P59' might be similar to 'P559'
# - 'P59' might be similar to 'P569'
# - 'P59' might be similar to 'P579'
# - 'P59' might be similar to 'P589'
# - 'P59' might be similar to 'P590'
# - 'P59' might be similar to 'P591'
# - 'P59' might be similar to 'P592'
# - 'P59' might be similar to 'P593'
# - 'P59' might be similar to 'P594'
# - 'P59' might be similar to 'P595'
# - 'P59' might be similar to 'P596'
# - 'P59' might be similar to 'P597'
# - 'P59' might be similar to 'P598'
# - 'P59' might be similar to 'P599'
# - 'P59' might be similar to 'P659'
# - 'P59' might be similar to 'P759'
# - 'P59' might be similar to 'P859'
# - 'P59' might be similar to 'P959'
# - 'P60' might be similar to 'P160'
# - 'P60' might be similar to 'P260'
# - 'P60' might be similar to 'P360'
# - 'P60' might be similar to 'P460'
# - 'P60' might be similar to 'P560'
# - 'P60' might be similar to 'P600'
# - 'P60' might be similar to 'P601'
# - 'P60' might be similar to 'P602'
# - 'P60' might be similar to 'P603'
# - 'P60' might be similar to 'P604'
# - 'P60' might be similar to 'P605'
# - 'P60' might be similar to 'P606'
# - 'P60' might be similar to 'P607'
# - 'P60' might be similar to 'P608'
# - 'P60' might be similar to 'P609'
# - 'P60' might be similar to 'P610'
# - 'P60' might be similar to 'P620'
# - 'P60' might be similar to 'P630'
# - 'P60' might be similar to 'P640'
# - 'P60' might be similar to 'P650'
# ...
# - 'P785' might be similar to 'P2785'
# - 'P786' might be similar to 'P1786'
# - 'P786' might be similar to 'P2786'
# - 'P787' might be similar to 'P1787'
# - 'P787' might be similar to 'P2787'
# - 'P788' might be similar to 'P1788'
# - 'P788' might be similar to 'P2788'
# - 'P789' might be similar to 'P1789'
# - 'P789' might be similar to 'P2789'
# - 'P790' might be similar to 'P1790'
# - 'P790' might be similar to 'P2790'
# - 'P791' might be similar to 'P1791'
# - 'P791' might be similar to 'P2791'
# - 'P792' might be similar to 'P1792'
# - 'P792' might be similar to 'P2792'
# - 'P793' might be similar to 'P1793'
# - 'P793' might be similar to 'P2793'
# - 'P794' might be similar to 'P1794'
# - 'P794' might be similar to 'P2794'
# - 'P795' might be similar to 'P1795'
# - 'P795' might be similar to 'P2795'
# - 'P796' might be similar to 'P1796'
# - 'P796' might be similar to 'P2796'
# - 'P797' might be similar to 'P1797'
# - 'P797' might be similar to 'P2797'
# - 'P798' might be similar to 'P1798'
# - 'P798' might be similar to 'P2798'
# - 'P799' might be similar to 'P1799'
# - 'P799' might be similar to 'P2799'
# - 'P800' might be similar to 'P1800'
# - 'P800' might be similar to 'P2800'
# - 'P801' might be similar to 'P1801'
# - 'P801' might be similar to 'P2801'
# - 'P802' might be similar to 'P1802'
# - 'P802' might be similar to 'P2802'
# - 'P803' might be similar to 'P1803'
# - 'P803' might be similar to 'P2803'
# - 'P804' might be similar to 'P1804'
# - 'P804' might be similar to 'P2804'
# - 'P805' might be similar to 'P1805'
# - 'P805' might be similar to 'P2805'
# - 'P806' might be similar to 'P1806'
# - 'P806' might be similar to 'P2806'
# - 'P807' might be similar to 'P1807'
# - 'P807' might be similar to 'P2807'
# - 'P808' might be similar to 'P1808'
# - 'P808' might be similar to 'P2808'
# - 'P809' might be similar to 'P1809'
# - 'P809' might be similar to 'P2809'
# - 'P810' might be similar to 'P1810'
# - 'P810' might be similar to 'P2810'
# - 'P811' might be similar to 'P1811'
# - 'P811' might be similar to 'P2811'
# - 'P812' might be similar to 'P1812'
# - 'P812' might be similar to 'P2812'
# - 'P813' might be similar to 'P1813'
# - 'P813' might be similar to 'P2813'
# - 'P814' might be similar to 'P1814'
# - 'P814' might be similar to 'P2814'
# - 'P815' might be similar to 'P1815'
# - 'P815' might be similar to 'P2815'
# - 'P816' might be similar to 'P1816'
# - 'P816' might be similar to 'P2816'
# - 'P817' might be similar to 'P1817'
# - 'P817' might be similar to 'P2817'
# - 'P818' might be similar to 'P1818'
# - 'P818' might be similar to 'P2818'
# - 'P819' might be similar to 'P1819'
# - 'P819' might be similar to 'P2819'
# - 'P820' might be similar to 'P1820'
# - 'P820' might be similar to 'P2820'
# - 'P821' might be similar to 'P1821'
# - 'P821' might be similar to 'P2821'
# - 'P822' might be similar to 'P1822'
# - 'P822' might be similar to 'P2822'
# - 'P823' might be similar to 'P1823'
# - 'P823' might be similar to 'P2823'
# - 'P824' might be similar to 'P1824'
# - 'P824' might be similar to 'P2824'
# - 'P825' might be similar to 'P1825'
# - 'P825' might be similar to 'P2825'
# - 'P826' might be similar to 'P1826'
# - 'P826' might be similar to 'P2826'
# - 'P827' might be similar to 'P1827'
# - 'P827' might be similar to 'P2827'
# - 'P828' might be similar to 'P1828'
# - 'P828' might be similar to 'P2828'
# - 'P829' might be similar to 'P1829'
# - 'P829' might be similar to 'P2829'
# - 'P830' might be similar to 'P1830'
# - 'P830' might be similar to 'P2830'
# - 'P831' might be similar to 'P1831'
# - 'P831' might be similar to 'P2831'
# - 'P832' might be similar to 'P1832'
# - 'P832' might be similar to 'P2832'
# - 'P833' might be similar to 'P1833'
# - 'P833' might be similar to 'P2833'
# - 'P834' might be similar to 'P1834'
# - 'P834' might be similar to 'P2834'
# - 'P835' might be similar to 'P1835'
# - 'P835' might be similar to 'P2835'
# - 'P836' might be similar to 'P1836'
# - 'P836' might be similar to 'P2836'
# - 'P837' might be similar to 'P1837'
# - 'P837' might be similar to 'P2837'
# - 'P838' might be similar to 'P1838'
# - 'P838' might be similar to 'P2838'
# - 'P839' might be similar to 'P1839'
# - 'P839' might be similar to 'P2839'
# - 'P840' might be similar to 'P1840'
# - 'P840' might be similar to 'P2840'
# - 'P841' might be similar to 'P1841'
# - 'P841' might be similar to 'P2841'
# - 'P842' might be similar to 'P1842'
# - 'P842' might be similar to 'P2842'
# - 'P843' might be similar to 'P1843'
# - 'P843' might be similar to 'P2843'
# - 'P844' might be similar to 'P1844'
# - 'P844' might be similar to 'P2844'
# - 'P845' might be similar to 'P1845'
# - 'P845' might be similar to 'P2845'
# - 'P846' might be similar to 'P1846'
# - 'P846' might be similar to 'P2846'
# - 'P847' might be similar to 'P1847'
# - 'P847' might be similar to 'P2847'
# - 'P848' might be similar to 'P1848'
# - 'P848' might be similar to 'P2848'
# - 'P849' might be similar to 'P1849'
# - 'P849' might be similar to 'P2849'
# - 'P850' might be similar to 'P1850'
# - 'P850' might be similar to 'P2850'
# - 'P851' might be similar to 'P1851'
# - 'P851' might be similar to 'P2851'
# - 'P852' might be similar to 'P1852'
# - 'P852' might be similar to 'P2852'
# - 'P853' might be similar to 'P1853'
# - 'P853' might be similar to 'P2853'
# - 'P854' might be similar to 'P1854'
# - 'P854' might be similar to 'P2854'
# - 'P855' might be similar to 'P1855'
# - 'P855' might be similar to 'P2855'
# - 'P856' might be similar to 'P1856'
# - 'P856' might be similar to 'P2856'
# - 'P857' might be similar to 'P1857'
# - 'P857' might be similar to 'P2857'
# - 'P858' might be similar to 'P1858'
# - 'P858' might be similar to 'P2858'
# - 'P859' might be similar to 'P1859'
# - 'P859' might be similar to 'P2859'
# - 'P860' might be similar to 'P1860'
# - 'P860' might be similar to 'P2860'
# - 'P861' might be similar to 'P1861'
# - 'P861' might be similar to 'P2861'
# - 'P862' might be similar to 'P1862'
# - 'P862' might be similar to 'P2862'
# - 'P863' might be similar to 'P1863'
# - 'P863' might be similar to 'P2863'
# - 'P864' might be similar to 'P1864'
# - 'P864' might be similar to 'P2864'
# - 'P865' might be similar to 'P1865'
# - 'P865' might be similar to 'P2865'
# - 'P866' might be similar to 'P1866'
# - 'P866' might be similar to 'P2866'
# - 'P867' might be similar to 'P1867'
# - 'P867' might be similar to 'P2867'
# - 'P868' might be similar to 'P1868'
# - 'P868' might be similar to 'P2868'
# - 'P869' might be similar to 'P1869'
# - 'P869' might be similar to 'P2869'
# - 'P870' might be similar to 'P1870'
# - 'P870' might be similar to 'P2870'
# - 'P871' might be similar to 'P1871'
# - 'P871' might be similar to 'P2871'
# - 'P872' might be similar to 'P1872'
# - 'P872' might be similar to 'P2872'
# - 'P873' might be similar to 'P1873'
# - 'P873' might be similar to 'P2873'
# - 'P874' might be similar to 'P1874'
# - 'P874' might be similar to 'P2874'
# - 'P875' might be similar to 'P1875'
# - 'P875' might be similar to 'P2875'
# - 'P876' might be similar to 'P1876'
# - 'P876' might be similar to 'P2876'
# - 'P877' might be similar to 'P1877'
# - 'P877' might be similar to 'P2877'
# - 'P878' might be similar to 'P1878'
# - 'P878' might be similar to 'P2878'
# - 'P879' might be similar to 'P1879'
# - 'P879' might be similar to 'P2879'
# - 'P880' might be similar to 'P1880'
# - 'P880' might be similar to 'P2880'
# - 'P881' might be similar to 'P1881'
# - 'P881' might be similar to 'P2881'
# - 'P882' might be similar to 'P1882'
# - 'P882' might be similar to 'P2882'
# - 'P883' might be similar to 'P1883'
# - 'P883' might be similar to 'P2883'
# - 'P884' might be similar to 'P1884'
# - 'P884' might be similar to 'P2884'
# - 'P885' might be similar to 'P1885'
# - 'P885' might be similar to 'P2885'
# - 'P886' might be similar to 'P1886'
# - 'P886' might be similar to 'P2886'
# - 'P887' might be similar to 'P1887'
# - 'P887' might be similar to 'P2887'
# - 'P888' might be similar to 'P1888'
# - 'P888' might be similar to 'P2888'
# - 'P889' might be similar to 'P1889'
# - 'P889' might be similar to 'P2889'
# - 'P890' might be similar to 'P1890'
# - 'P890' might be similar to 'P2890'
# - 'P891' might be similar to 'P1891'
# - 'P891' might be similar to 'P2891'
# - 'P892' might be similar to 'P1892'
# - 'P892' might be similar to 'P2892'
# - 'P893' might be similar to 'P1893'
# - 'P893' might be similar to 'P2893'
# - 'P894' might be similar to 'P1894'
# - 'P894' might be similar to 'P2894'
# - 'P895' might be similar to 'P1895'
# - 'P895' might be similar to 'P2895'
# - 'P896' might be similar to 'P1896'
# - 'P896' might be similar to 'P2896'
# - 'P897' might be similar to 'P1897'
# - 'P897' might be similar to 'P2897'
# - 'P898' might be similar to 'P1898'
# - 'P898' might be similar to 'P2898'
# - 'P899' might be similar to 'P1899'
# - 'P899' might be similar to 'P2899'
# - 'P900' might be similar to 'P1900'
# - 'P900' might be similar to 'P2900'
# - 'P901' might be similar to 'P1901'
# - 'P901' might be similar to 'P2901'
# - 'P902' might be similar to 'P1902'
# - 'P902' might be similar to 'P2902'
# - 'P903' might be similar to 'P1903'
# - 'P903' might be similar to 'P2903'
# - 'P904' might be similar to 'P1904'
# - 'P904' might be similar to 'P2904'
# - 'P905' might be similar to 'P1905'
# - 'P905' might be similar to 'P2905'
# - 'P906' might be similar to 'P1906'
# - 'P906' might be similar to 'P2906'
# - 'P907' might be similar to 'P1907'
# - 'P907' might be similar to 'P2907'
# - 'P908' might be similar to 'P1908'
# - 'P908' might be similar to 'P2908'
# - 'P909' might be similar to 'P1909'
# - 'P909' might be similar to 'P2909'
# - 'P910' might be similar to 'P1910'
# - 'P910' might be similar to 'P2910'
# - 'P911' might be similar to 'P1911'
# - 'P911' might be similar to 'P2911'
# - 'P912' might be similar to 'P1912'
# - 'P912' might be similar to 'P2912'
# - 'P913' might be similar to 'P1913'
# - 'P913' might be similar to 'P2913'
# - 'P914' might be similar to 'P1914'
# - 'P914' might be similar to 'P2914'
# - 'P915' might be similar to 'P1915'
# - 'P915' might be similar to 'P2915'
# - 'P916' might be similar to 'P1916'
# - 'P916' might be similar to 'P2916'
# - 'P917' might be similar to 'P1917'
# - 'P917' might be similar to 'P2917'
# - 'P918' might be similar to 'P1918'
# - 'P918' might be similar to 'P2918'
# - 'P919' might be similar to 'P1919'
# - 'P919' might be similar to 'P2919'
# - 'P920' might be similar to 'P1920'
# - 'P920' might be similar to 'P2920'
# - 'P921' might be similar to 'P1921'
# - 'P921' might be similar to 'P2921'
# - 'P922' might be similar to 'P1922'
# - 'P922' might be similar to 'P2922'
# - 'P923' might be similar to 'P1923'
# - 'P923' might be similar to 'P2923'
# - 'P924' might be similar to 'P1924'
# - 'P924' might be similar to 'P2924'
# - 'P925' might be similar to 'P1925'
# - 'P925' might be similar to 'P2925'
# - 'P926' might be similar to 'P1926'
# - 'P926' might be similar to 'P2926'
# - 'P927' might be similar to 'P1927'
# - 'P927' might be similar to 'P2927'
# - 'P928' might be similar to 'P1928'
# - 'P928' might be similar to 'P2928'
# - 'P929' might be similar to 'P1929'
# - 'P929' might be similar to 'P2929'
# - 'P930' might be similar to 'P1930'
# - 'P930' might be similar to 'P2930'
# - 'P931' might be similar to 'P1931'
# - 'P931' might be similar to 'P2931'
# - 'P932' might be similar to 'P1932'
# - 'P932' might be similar to 'P2932'
# - 'P933' might be similar to 'P1933'
# - 'P933' might be similar to 'P2933'
# - 'P934' might be similar to 'P1934'
# - 'P934' might be similar to 'P2934'
# - 'P935' might be similar to 'P1935'
# - 'P935' might be similar to 'P2935'
# - 'P936' might be similar to 'P1936'
# - 'P936' might be similar to 'P2936'
# - 'P937' might be similar to 'P1937'
# - 'P937' might be similar to 'P2937'
# - 'P938' might be similar to 'P1938'
# - 'P938' might be similar to 'P2938'
# - 'P939' might be similar to 'P1939'
# - 'P939' might be similar to 'P2939'
# - 'P940' might be similar to 'P1940'
# - 'P940' might be similar to 'P2940'
# - 'P941' might be similar to 'P1941'
# - 'P941' might be similar to 'P2941'
# - 'P942' might be similar to 'P1942'
# - 'P942' might be similar to 'P2942'
# - 'P943' might be similar to 'P1943'
# - 'P943' might be similar to 'P2943'
# - 'P944' might be similar to 'P1944'
# - 'P944' might be similar to 'P2944'
# - 'P945' might be similar to 'P1945'
# - 'P945' might be similar to 'P2945'
# - 'P946' might be similar to 'P1946'
# - 'P946' might be similar to 'P2946'
# - 'P947' might be similar to 'P1947'
# - 'P947' might be similar to 'P2947'
# - 'P948' might be similar to 'P1948'
# - 'P948' might be similar to 'P2948'
# - 'P949' might be similar to 'P1949'
# - 'P949' might be similar to 'P2949'
# - 'P950' might be similar to 'P1950'
# - 'P950' might be similar to 'P2950'
# - 'P951' might be similar to 'P1951'
# - 'P951' might be similar to 'P2951'
# - 'P952' might be similar to 'P1952'
# - 'P952' might be similar to 'P2952'
# - 'P953' might be similar to 'P1953'
# - 'P953' might be similar to 'P2953'
# - 'P954' might be similar to 'P1954'
# - 'P954' might be similar to 'P2954'
# - 'P955' might be similar to 'P1955'
# - 'P955' might be similar to 'P2955'
# - 'P956' might be similar to 'P1956'
# - 'P956' might be similar to 'P2956'
# - 'P957' might be similar to 'P1957'
# - 'P957' might be similar to 'P2957'
# - 'P958' might be similar to 'P1958'
# - 'P958' might be similar to 'P2958'
# - 'P959' might be similar to 'P1959'
# - 'P959' might be similar to 'P2959'
# - 'P960' might be similar to 'P1960'
# - 'P960' might be similar to 'P2960'
# - 'P961' might be similar to 'P1961'
# - 'P961' might be similar to 'P2961'
# - 'P962' might be similar to 'P1962'
# - 'P962' might be similar to 'P2962'
# - 'P963' might be similar to 'P1963'
# - 'P963' might be similar to 'P2963'
# - 'P964' might be similar to 'P1964'
# - 'P964' might be similar to 'P2964'
# - 'P965' might be similar to 'P1965'
# - 'P965' might be similar to 'P2965'
# - 'P966' might be similar to 'P1966'
# - 'P966' might be similar to 'P2966'
# - 'P967' might be similar to 'P1967'
# - 'P967' might be similar to 'P2967'
# - 'P968' might be similar to 'P1968'
# - 'P968' might be similar to 'P2968'
# - 'P969' might be similar to 'P1969'
# - 'P969' might be similar to 'P2969'
# - 'P970' might be similar to 'P1970'
# - 'P970' might be similar to 'P2970'
# - 'P971' might be similar to 'P1971'
# - 'P971' might be similar to 'P2971'
# - 'P972' might be similar to 'P1972'
# - 'P972' might be similar to 'P2972'
# - 'P973' might be similar to 'P1973'
# - 'P973' might be similar to 'P2973'
# - 'P974' might be similar to 'P1974'
# - 'P974' might be similar to 'P2974'
# - 'P975' might be similar to 'P1975'
# - 'P975' might be similar to 'P2975'
# - 'P976' might be similar to 'P1976'
# - 'P976' might be similar to 'P2976'
# - 'P977' might be similar to 'P1977'
# - 'P977' might be similar to 'P2977'
# - 'P978' might be similar to 'P1978'
# - 'P978' might be similar to 'P2978'
# - 'P979' might be similar to 'P1979'
# - 'P979' might be similar to 'P2979'
# - 'P980' might be similar to 'P1980'
# - 'P980' might be similar to 'P2980'
# - 'P981' might be similar to 'P1981'
# - 'P981' might be similar to 'P2981'
# - 'P982' might be similar to 'P1982'
# - 'P982' might be similar to 'P2982'
# - 'P983' might be similar to 'P1983'
# - 'P983' might be similar to 'P2983'
# - 'P984' might be similar to 'P1984'
# - 'P984' might be similar to 'P2984'
# - 'P985' might be similar to 'P1985'
# - 'P985' might be similar to 'P2985'
# - 'P986' might be similar to 'P1986'
# - 'P986' might be similar to 'P2986'
# - 'P987' might be similar to 'P1987'
# - 'P987' might be similar to 'P2987'
# - 'P988' might be similar to 'P1988'
# - 'P988' might be similar to 'P2988'
# - 'P989' might be similar to 'P1989'
# - 'P989' might be similar to 'P2989'
# - 'P990' might be similar to 'P1990'
# - 'P990' might be similar to 'P2990'
# - 'P991' might be similar to 'P1991'
# - 'P991' might be similar to 'P2991'
# - 'P992' might be similar to 'P1992'
# - 'P992' might be similar to 'P2992'
# - 'P993' might be similar to 'P1993'
# - 'P993' might be similar to 'P2993'
# - 'P994' might be similar to 'P1994'
# - 'P994' might be similar to 'P2994'
# - 'P995' might be similar to 'P1995'
# - 'P995' might be similar to 'P2995'
# - 'P996' might be similar to 'P1996'
# - 'P996' might be similar to 'P2996'
# - 'P997' might be similar to 'P1997'
# - 'P997' might be similar to 'P2997'
# - 'P998' might be similar to 'P1998'
# - 'P998' might be similar to 'P2998'
# - 'P999' might be similar to 'P1999'
# - 'P999' might be similar to 'P2999'
# Potential spelling errors in column 'Ntm_Speciality':
# - 'UROLOGY' might be similar to 'NEUROLOGY'

# %% [markdown]
# ## Checking for Duplicates

# %%
duplicate_columns = df.columns[df.columns.duplicated()]

if duplicate_columns.empty:
    print("No duplicate columns found!")
else:
    print("Duplicate Columns:", duplicate_columns)


duplicate_rows = df[df.duplicated()]

if duplicate_rows.empty:
    print('No duplicate rows found!')
else:
    print("Duplicate Rows:", duplicate_rows)
# Out:
# No duplicate columns found!
# No duplicate rows found!

# %% [markdown]
# ## Check for NaN Values

# %%
util.show_nan_all_columns(df)
# Out:
# NaN Counts:
# Ptid                                                                  0
# Concom_Cephalosporins                                                 0
# Risk_Osteogenesis_Imperfecta                                          0
# Risk_Type_1_Insulin_Dependent_Diabetes                                0
# Concom_Viral_Vaccines                                                 0
# Concom_Anaesthetics_General                                           0
# Concom_Broad_Spectrum_Penicillins                                     0
# Concom_Macrolides_And_Similar_Types                                   0
# Concom_Fluoroquinolones                                               0
# Comorb_Disorders_of_lipoprotein_metabolism_and_other_lipidemias       0
# Concom_Anti_Depressants_And_Mood_Stabilisers                          0
# Concom_Systemic_Corticosteroids_Plain                                 0
# Concom_Narcotics                                                      0
# Concom_Cholesterol_And_Triglyceride_Regulating_Preparations           0
# Comorb_Gastro_esophageal_reflux_disease                               0
# Comorb_Personal_history_of_malignant_neoplasm                         0
# Risk_Rheumatoid_Arthritis                                             0
# Risk_Untreated_Chronic_Hyperthyroidism                                0
# Risk_Untreated_Chronic_Hypogonadism                                   0
# Risk_Untreated_Early_Menopause                                        0
# Risk_Patient_Parent_Fractured_Their_Hip                               0
# Risk_Smoking_Tobacco                                                  0
# Risk_Chronic_Malnutrition_Or_Malabsorption                            0
# Risk_Chronic_Liver_Disease                                            0
# Risk_Family_History_Of_Osteoporosis                                   0
# Risk_Low_Calcium_Intake                                               0
# Risk_Vitamin_D_Insufficiency                                          0
# Risk_Poor_Health_Frailty                                              0
# Risk_Excessive_Thinness                                               0
# Risk_Hysterectomy_Oophorectomy                                        0
# Risk_Estrogen_Deficiency                                              0
# Risk_Immobilization                                                   0
# Risk_Recurring_Falls                                                  0
# Comorb_Osteoporosis_without_current_pathological_fracture             0
# Comorb_Other_Disorders_Of_Bone_Density_And_Structure                  0
# Persistency_Flag                                                      0
# Ntm_Speciality_Bucket                                                 0
# Frag_Frac_During_Rx                                                   0
# Frag_Frac_Prior_Ntm                                                   0
# Dexa_During_Rx                                                        0
# Dexa_Freq_During_Rx                                                   0
# Gluco_Record_During_Rx                                                0
# Gluco_Record_Prior_Ntm                                                0
# Ntm_Specialist_Flag                                                   0
# Comorb_Personal_History_Of_Other_Diseases_And_Conditions              0
# Ntm_Speciality                                                        0
# Age_Bucket                                                            0
# Region                                                                0
# Ethnicity                                                             0
# Race                                                                  0
# Gender                                                                0
# Risk_Segment_Prior_Ntm                                                0
# Tscore_Bucket_Prior_Ntm                                               0
# Risk_Segment_During_Rx                                                0
# Tscore_Bucket_During_Rx                                               0
# Change_T_Score                                                        0
# Change_Risk_Segment                                                   0
# Adherent_Flag                                                         0
# Idn_Indicator                                                         0
# Injectable_Experience_During_Rx                                       0
# Comorb_Encounter_For_Screening_For_Malignant_Neoplasms                0
# Comorb_Encounter_For_Immunization                                     0
# Comorb_Encntr_For_General_Exam_W_O_Complaint,_Susp_Or_Reprtd_Dx       0
# Comorb_Vitamin_D_Deficiency                                           0
# Comorb_Other_Joint_Disorder_Not_Elsewhere_Classified                  0
# Comorb_Encntr_For_Oth_Sp_Exam_W_O_Complaint_Suspected_Or_Reprtd_Dx    0
# Comorb_Long_Term_Current_Drug_Therapy                                 0
# Comorb_Dorsalgia                                                      0
# Count_Of_Risks                                                        0
# dtype: int64

# %% [markdown]
# No NaNs found.
